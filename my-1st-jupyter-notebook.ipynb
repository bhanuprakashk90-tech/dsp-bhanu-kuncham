# %%
import numpy as np
import random


my_array = np.random.randint(10, 100, size=(10, 3))
display(my_array)
# Out:
# array([[62, 60, 75],
#        [26, 86, 92],
#        [81, 40, 20],
#        [31, 95, 26],
#        [71, 24, 98],
#        [75, 62, 18],
#        [52, 97, 15],
#        [99, 47, 24],
#        [66, 16, 39],
#        [12, 23, 43]])
