# %%
import numpy as np
import random


my_array = np.random.randint(10, 100, size=(10, 3))
display(my_array)
# Out:
# array([[17, 71, 20],
#        [43, 19, 12],
#        [93, 44, 46],
#        [42, 91, 69],
#        [68, 83, 59],
#        [71, 59, 40],
#        [48, 30, 40],
#        [16, 92, 51],
#        [43, 29, 87],
#        [39, 24, 72]], dtype=int32)
