# %% [markdown]
# # Model Building

# %%
import sys
from pathlib import Path

# Add parent directory to path to import house_prices module
sys.path.insert(0, str(Path.cwd().parent))

# %%
from house_prices.train import build_model

model_performance_dict = build_model('../data/train.csv')
print(model_performance_dict)
# Out:
# {'rmsle': 0.1745, 'r2': 0.84}

# %% [markdown]
# # Model Inference

# %%
from house_prices.inference import make_predictions

predictions = make_predictions('../data/test.csv')
predictions
# Out:
# array([132627.66301643, 163533.21168884, 164821.95091833, ...,
#        155218.8554059 , 129303.65576538, 215506.73510252], shape=(1459,))
